# %%
"""
* https://www.anthropic.com/engineering/building-effective-agents
* https://github.com/dabidstudio/python-ai-agents
"""
# Out:
# '\n* https://www.anthropic.com/engineering/building-effective-agents\n* https://github.com/dabidstudio/python-ai-agents\n'

# %%
from openai import OpenAI, AsyncOpenAI

# %%
client = OpenAI()

def llm_call(prompt: str,  model: str = "gpt-4o-mini") -> str:
    messages = []
    messages.append({"role": "user", "content": prompt})
    chat_completion = client.chat.completions.create(
        model=model,
        messages=messages,
    )
    return chat_completion.choices[0].message.content

# %%
aclient = AsyncOpenAI()

async def llm_call_async(prompt: str,  model: str = "gpt-4o-mini") -> str:
    messages = []
    messages.append({"role": "user", "content": prompt})
    chat_completion = await aclient.chat.completions.create(
        model=model,
        messages=messages,
    )    
    return chat_completion.choices[0].message.content

# %% [markdown]
# # prompt chaining

# %%
from typing import List

def prompt_chain_workflow(initial_input: str, prompt_chain: List[str]) -> List[str]:
    response_chain = []
    response = initial_input

    for i, prompt in enumerate(prompt_chain, 1):
        print(f"\n==== 단계 {i} ====\n")
        final_prompt = f"{prompt}\n사용자 입력:\n{response}"
        print(f"🔹 프롬프트:\n{final_prompt}\n")

        response = llm_call(final_prompt)
        response_chain.append(response)
        print(f"✅ 응답:\n{response}\n")

    return response_chain


## 처음 입력값을 계속 유지해야 하는 경우!
def prompt_chain_workflow_2(initial_input: str, prompt_chain: List[str]) -> List[str]:
    response_chain = []
    response = initial_input

    for i, prompt in enumerate(prompt_chain, 1):
        print(f"\n==== 단계 {i} ====\n")
        final_prompt = f"{prompt}\n\n🔹 문맥(Context):\n{response}\n🔹 사용자 입력: {initial_input}"
        print(f"🔹 프롬프트:\n{final_prompt}\n")

        response = llm_call(final_prompt)
        response_chain.append(response)
        print(f"✅ 응답:\n{response}\n")

    return response_chain


initial_input ="""
나는 여름 휴가를 계획 중이야. 따뜻한 날씨를 좋아하고, 자연 경관과 역사적인 장소를 둘러보는 걸 좋아해.
어떤 여행지가 나에게 적합할까?
"""

# 프롬프트 체인: LLM이 단계적으로 여행을 계획하도록 유도
prompt_chain = [
    ## 여행 후보지 3곳을 추천하고 그 이유를 설명
"""사용자의 여행 취향을 바탕으로 적합한 여행지 3곳을 추천하세요. 
- 먼저 사용자가 입력한 희망사항을 요약해줘
- 사용자가 입력한 희망사항을 반영해서 왜 적합한 여행지인지 설명해주세요
- 각 여행지의 기후, 주요 관광지, 활동 등을 설명하세요.
""",

    ## 여행지 1곳을 선택하고 활동 5가지 나열
"""다음 여행지 3곳 중 하나를 선택하세요. 선택한 여행지 알려주세요. 그리고 선택한 이유를 설명해주세요.
- 해당 여행지에서 즐길 수 있는 주요 활동 5가지를 나열하세요. 
- 활동은 자연 탐방, 역사 탐방, 음식 체험 등 다양한 범주에서 포함되도록 하세요.
""",

    ## 선택한 여행지에서 하루 일정 계획
"""사용자가 하루 동안 이 여행지에서 시간을 보낼 계획입니다. 
- 오전, 오후, 저녁으로 나누어 일정을 짜고, 각 시간대에 어떤 활동을 하면 좋을지 설명하세요.
""",
]

responses = prompt_chain_workflow_2(initial_input,prompt_chain)

final_answer = responses[-1]
# Out:
# ==== 단계 1 ====
#
# 🔹 프롬프트:
# 사용자의 여행 취향을 바탕으로 적합한 여행지 3곳을 추천하세요.
# - 먼저 사용자가 입력한 희망사항을 요약해줘
# - 사용자가 입력한 희망사항을 반영해서 왜 적합한 여행지인지 설명해주세요
# - 각 여행지의 기후, 주요 관광지, 활동 등을 설명하세요.
#
#
# 🔹 문맥(Context):
#
# 나는 여름 휴가를 계획 중이야. 따뜻한 날씨를 좋아하고, 자연 경관과 역사적인 장소를 둘러보는 걸 좋아해.
# 어떤 여행지가 나에게 적합할까?
#
# 🔹 사용자 입력:
# 나는 여름 휴가를 계획 중이야. 따뜻한 날씨를 좋아하고, 자연 경관과 역사적인 장소를 둘러보는 걸 좋아해.
# 어떤 여행지가 나에게 적합할까?
#
#
# ✅ 응답:
# ## 사용자 희망사항 요약:
# - 여름 휴가를 계획 중
# - 따뜻한 날씨 선호
# - 자연 경관과 역사적인 장소 탐방을 즐김
#
# ## 추천 여행지:
# 1. **그리스, 산토리니**
# 2. **이탈리아, 토스카나**
# 3. **멕시코, 유카탄 반도**
#
# ### 1. 그리스, 산토리니
# - **적합한 이유**: 산토리니는 따뜻한 여름 날씨, 아름다운 자연 경관(특히 해변과 일몰)과 함께 고대 유적지와 마을의 역사적인 매력을 제공합니다.
# - **기후**: 여름에는 평균 기온이 25~30도 사이로 따뜻하며 맑은 날씨가 이어집니다.
# - **주요 관광지 및 활동**:
#   - **오이아 마을**: 독특한 흰색 집들과 아름다운 일몰로 유명합니다.
#   - **고대 티라 유적지**: 고대 그리스 문명의 흔적을 느낄 수 있는 유적지로 관광객에게 인기가 있습니다.
#   - **화산 투어**: 화산섬을 둘러보며 스노클링이나 하이킹을 즐길 수 있습니다.
#
# ### 2. 이탈리아, 토스카나
# - **적합한 이유**: 토스카나는 따뜻한 기후와 아름다운 자연 경관, 풍부한 역사적 유적지를 갖춘 지역으로, 자연과 역사 탐방을 동시에 즐길 수 있습니다.
# - **기후**: 여름철 평균 기온은 25~35도로 따뜻하고, 햇살이 가득한 날이 많습니다.
# - **주요 관광지 및 활동**:
#   - **피렌체**: 조르조네의 ‘다비드’와 같은 예술작품과 르네상스 건축을 탐방할 수 있습니다.
#   - **산 지미냐노**: 중세 도시 풍경을 느낄 수 있는 곳으로, 탑들이 줄지어 있는 풍경이 인상적입니다.
#   - **포도밭 투어**: 이 지역의 세계적인 와인을 즐기며 포도밭을 탐방하는 것도 가능하여 로맨틱한 경험을 제공합니다.
#
# ### 3. 멕시코, 유카탄 반도
# - **적합한 이유**: 유카탄 반도는 따뜻한 날씨와 풍부한 자연경관, 마야 문명의 역사적인 유적지가 조화를 이루는 여행지가 됩니다.
# - **기후**: 여름에는 평균 기온이 30~35도이며, 강렬한 햇볕이 특징입니다.
# - **주요 관광지 및 활동**:
#   - **치첸 이트사**: 마야 문명 세계의 대표적인 유적지로, 피라미드와 고대 도시가 잘 보존되어 있습니다.
#   - **센ote 탐방**: 자연적으로 형성된 우물로 맑은 물에서 수영하거나 스노클링을 즐길 수 있습니다.
#   - **코바**: 울창한 정글 속에 숨겨진 고대 마야의 유적을 탐방하고 자전거 투어를 즐길 수 있습니다.
#
# 이 세 여행지는 모두 따뜻한 여름 날씨 속에서 자연과 역사를 동시에 즐길 수 있는 최적의 장소들입니다. 각각의 매력을 느끼며 여러분의 기억에 남는 여름 휴가를 즐기세요!
#
#
# ==== 단계 2 ====
#
# 🔹 프롬프트:
# 다음 여행지 3곳 중 하나를 선택하세요. 선택한 여행지 알려주세요. 그리고 선택한 이유를 설명해주세요.
# - 해당 여행지에서 즐길 수 있는 주요 활동 5가지를 나열하세요.
# - 활동은 자연 탐방, 역사 탐방, 음식 체험 등 다양한 범주에서 포함되도록 하세요.
#
#
# 🔹 문맥(Context):
# ## 사용자 희망사항 요약:
# - 여름 휴가를 계획 중
# - 따뜻한 날씨 선호
# - 자연 경관과 역사적인 장소 탐방을 즐김
#
# ## 추천 여행지:
# 1. **그리스, 산토리니**
# 2. **이탈리아, 토스카나**
# 3. **멕시코, 유카탄 반도**
#
# ### 1. 그리스, 산토리니
# - **적합한 이유**: 산토리니는 따뜻한 여름 날씨, 아름다운 자연 경관(특히 해변과 일몰)과 함께 고대 유적지와 마을의 역사적인 매력을 제공합니다.
# - **기후**: 여름에는 평균 기온이 25~30도 사이로 따뜻하며 맑은 날씨가 이어집니다.
# - **주요 관광지 및 활동**:
#   - **오이아 마을**: 독특한 흰색 집들과 아름다운 일몰로 유명합니다.
#   - **고대 티라 유적지**: 고대 그리스 문명의 흔적을 느낄 수 있는 유적지로 관광객에게 인기가 있습니다.
#   - **화산 투어**: 화산섬을 둘러보며 스노클링이나 하이킹을 즐길 수 있습니다.
#
# ### 2. 이탈리아, 토스카나
# - **적합한 이유**: 토스카나는 따뜻한 기후와 아름다운 자연 경관, 풍부한 역사적 유적지를 갖춘 지역으로, 자연과 역사 탐방을 동시에 즐길 수 있습니다.
# - **기후**: 여름철 평균 기온은 25~35도로 따뜻하고, 햇살이 가득한 날이 많습니다.
# - **주요 관광지 및 활동**:
#   - **피렌체**: 조르조네의 ‘다비드’와 같은 예술작품과 르네상스 건축을 탐방할 수 있습니다.
#   - **산 지미냐노**: 중세 도시 풍경을 느낄 수 있는 곳으로, 탑들이 줄지어 있는 풍경이 인상적입니다.
#   - **포도밭 투어**: 이 지역의 세계적인 와인을 즐기며 포도밭을 탐방하는 것도 가능하여 로맨틱한 경험을 제공합니다.
#
# ### 3. 멕시코, 유카탄 반도
# - **적합한 이유**: 유카탄 반도는 따뜻한 날씨와 풍부한 자연경관, 마야 문명의 역사적인 유적지가 조화를 이루는 여행지가 됩니다.
# - **기후**: 여름에는 평균 기온이 30~35도이며, 강렬한 햇볕이 특징입니다.
# - **주요 관광지 및 활동**:
#   - **치첸 이트사**: 마야 문명 세계의 대표적인 유적지로, 피라미드와 고대 도시가 잘 보존되어 있습니다.
#   - **센ote 탐방**: 자연적으로 형성된 우물로 맑은 물에서 수영하거나 스노클링을 즐길 수 있습니다.
#   - **코바**: 울창한 정글 속에 숨겨진 고대 마야의 유적을 탐방하고 자전거 투어를 즐길 수 있습니다.
#
# 이 세 여행지는 모두 따뜻한 여름 날씨 속에서 자연과 역사를 동시에 즐길 수 있는 최적의 장소들입니다. 각각의 매력을 느끼며 여러분의 기억에 남는 여름 휴가를 즐기세요!
# 🔹 사용자 입력:
# 나는 여름 휴가를 계획 중이야. 따뜻한 날씨를 좋아하고, 자연 경관과 역사적인 장소를 둘러보는 걸 좋아해.
# 어떤 여행지가 나에게 적합할까?
#
#
# ✅ 응답:
# 제가 추천하는 여행지는 **이탈리아, 토스카나**입니다.
#
# ### 선택한 이유
# 토스카나는 따뜻한 여름 날씨 속에서 아름다운 자연 경관과 풍부한 역사적 유적지를 동시에 즐길 수 있는 곳입니다. 이 지역은 독특한 문화와 미식 경험을 제공하며, 그림 같은 풍경에서의 여유로운 시간을 보낼 수 있습니다. 특히, 토스카나의 포도밭과 중세 도시들은 꿈꾸는 듯한 경치를 제공합니다.
#
# ### 토스카나에서 즐길 수 있는 주요 활동 5가지
# 1. **피렌체 탐방**: 르네상스 미술과 건축을 즐길 수 있는 피렌체에서는 우피치 미술관과 두오모 성당을 꼭 방문해야 합니다.
#
# 2. **산 지미냐노 방문**: 중세 도시의 매력을 느낄 수 있는 산 지미냐노에서는 역사적인 탑과 아름다운 구시가지 거리를 구경할 수 있습니다.
#
# 3. **포도밭 및 와인 투어**: 토스카나의 세계적인 와인을 즐기며 포도밭을 탐방하는 프로그램에 참여하여 현지 와인과 요리를 맛보는 즐거움을 경험할 수 있습니다.
#
# 4. **자전거 투어**: 토스카나의 울창한 언덕을 자전거로 탐방하며 자연의 아름다움을 느낄 수 있습니다. 마을과 마을을 연결하는 경치 좋은 도로에서 여유롭게 자전거를 즐길 수 있습니다.
#
# 5. **요리 클래스**: 현지 식재료를 사용하여 이탈리안 요리를 배우고, 자신의 손으로 만든 음식을 즐기며 미각을 경험할 수 있는 기회를 제공합니다.
#
# 토스카나는 여러분의 여름 휴가에 필요한 모든 것을 갖춘 장소로, 잊지 못할 경험을 선사할 것입니다.
#
#
# ==== 단계 3 ====
#
# 🔹 프롬프트:
# 사용자가 하루 동안 이 여행지에서 시간을 보낼 계획입니다.
# - 오전, 오후, 저녁으로 나누어 일정을 짜고, 각 시간대에 어떤 활동을 하면 좋을지 설명하세요.
#
#
# 🔹 문맥(Context):
# 제가 추천하는 여행지는 **이탈리아, 토스카나**입니다.
#
# ### 선택한 이유
# 토스카나는 따뜻한 여름 날씨 속에서 아름다운 자연 경관과 풍부한 역사적 유적지를 동시에 즐길 수 있는 곳입니다. 이 지역은 독특한 문화와 미식 경험을 제공하며, 그림 같은 풍경에서의 여유로운 시간을 보낼 수 있습니다. 특히, 토스카나의 포도밭과 중세 도시들은 꿈꾸는 듯한 경치를 제공합니다.
#
# ### 토스카나에서 즐길 수 있는 주요 활동 5가지
# 1. **피렌체 탐방**: 르네상스 미술과 건축을 즐길 수 있는 피렌체에서는 우피치 미술관과 두오모 성당을 꼭 방문해야 합니다.
#
# 2. **산 지미냐노 방문**: 중세 도시의 매력을 느낄 수 있는 산 지미냐노에서는 역사적인 탑과 아름다운 구시가지 거리를 구경할 수 있습니다.
#
# 3. **포도밭 및 와인 투어**: 토스카나의 세계적인 와인을 즐기며 포도밭을 탐방하는 프로그램에 참여하여 현지 와인과 요리를 맛보는 즐거움을 경험할 수 있습니다.
#
# 4. **자전거 투어**: 토스카나의 울창한 언덕을 자전거로 탐방하며 자연의 아름다움을 느낄 수 있습니다. 마을과 마을을 연결하는 경치 좋은 도로에서 여유롭게 자전거를 즐길 수 있습니다.
#
# 5. **요리 클래스**: 현지 식재료를 사용하여 이탈리안 요리를 배우고, 자신의 손으로 만든 음식을 즐기며 미각을 경험할 수 있는 기회를 제공합니다.
#
# 토스카나는 여러분의 여름 휴가에 필요한 모든 것을 갖춘 장소로, 잊지 못할 경험을 선사할 것입니다.
# 🔹 사용자 입력:
# 나는 여름 휴가를 계획 중이야. 따뜻한 날씨를 좋아하고, 자연 경관과 역사적인 장소를 둘러보는 걸 좋아해.
# 어떤 여행지가 나에게 적합할까?
#
#
# ✅ 응답:
# 토스카나는 당신이 선호하는 따뜻한 날씨와 아름다운 자연 경관, 그리고 역사적인 장소들을 모두 갖춘 완벽한 여행지입니다! 아래는 하루 동안의 일정을 오전, 오후, 저녁으로 나누어 제안드립니다.
#
# ### 오전
# **피렌체 탐방**
# - **활동**: 피렌체의 주요 명소를 방문합니다. 먼저 **두오모 성당(Duomo)**에 올라가서 도시 전경을 감상하세요. 이후 **우피치 미술관(Uffizi Gallery)**을 찾아가 이탈리아 르네상스 미술의 걸작들을 감상합니다.
# - **설명**: 두오모에서의 전망은 토스카나의 아름다움을 한눈에 담을 수 있는 기회를 제공합니다. 우피치 미술관은 보티첼리, 미켈란젤로 등 유명 화가들의 작품을 소장하고 있어 예술을 좋아하는 당신에게는 흥미로운 경험이 될 것입니다.
#
# ### 오후
# **산 지미냐노 방문 & 포도밭 투어**
# - **활동**: 근교의 중세 도시인 **산 지미냐노(San Gimignano)**를 방문하여 그곳의 역사적인 탑과 구시가지를 산책합니다. 이후 포도밭 투어에 참여하여 다양한 토스카나 와인을 시음합니다.
# - **설명**: 산 지미냐노의 독특한 타워는 중세 시대의 매력을 대표하며, 좁은 골목길을 걷는 것 또한 즐거운 경험이 될 것입니다. 포도밭 투어에서는 현지 와인과 함께 간단한 스낵이 제공되어 미식 경험을 더욱 풍부하게 할 수 있습니다.
#
# ### 저녁
# **요리 클래스**
# - **활동**: 토스카나 전통 요리 클래스를 수강하여 현지 식재료로 이탈리안 요리를 만들어 보고, 자신이 만든 음식을 저녁으로 즐깁니다.
# - **설명**: 요리 클래스에서는 현지 셰프의 지도로 이탈리안 요리를 배우고, 그 과정에서 지역 문화에 대해 더 깊이 이해할 수 있습니다. 저녁이 끝난 후, 자신이 만든 요리를 맛보며 하루를 마무리하는 것은 잊지 못할 경험이 될 것입니다.
#
# 이러한 일정은 토스카나의 매력을 한껏 즐기면서, 자연과 역사, 미식을 동시에 경험할 수 있는 좋은 기회가 될 것입니다. 즐거운 여행 되세요!
#
# 토스카나는 당신이 선호하는 따뜻한 날씨와 아름다운 자연 경관, 그리고 역사적인 장소들을 모두 갖춘 완벽한 여행지입니다! 아래는 하루 동안의 일정을 오전, 오후, 저녁으로 나누어 제안드립니다.
#
# ### 오전
# **피렌체 탐방**
# - **활동**: 피렌체의 주요 명소를 방문합니다. 먼저 **두오모 성당(Duomo)**에 올라가서 도시 전경을 감상하세요. 이후 **우피치 미술관(Uffizi Gallery)**을 찾아가 이탈리아 르네상스 미술의 걸작들을 감상합니다.
# - **설명**: 두오모에서의 전망은 토스카나의 아름다움을 한눈에 담을 수 있는 기회를 제공합니다. 우피치 미술관은 보티첼리, 미켈란젤로 등 유명 화가들의 작품을 소장하고 있어 예술을 좋아하는 당신에게는 흥미로운 경험이 될 것입니다.
#
# ### 오후
# **산 지미냐노 방문 & 포도밭 투어**
# - **활동**: 근교의 중세 도시인 **산 지미냐노(San Gimignano)**를 방문하여 그곳의 역사적인 탑과 구시가지를 산책합니다. 이후 포도밭 투어에 참여하여 다양한 토스카나 와인을 시음합니다.
# - **설명**: 산 지미냐노의 독특한 타워는 중세 시대의 매력을 대표하며, 좁은 골목길을 걷는 것 또한 즐거운 경험이 될 것입니다. 포도밭 투어에서는 현지 와인과 함께 간단한 스낵이 제공되어 미식 경험을 더욱 풍부하게 할 수 있습니다.
#
# ### 저녁
# **요리 클래스**
# - **활동**: 토스카나 전통 요리 클래스를 수강하여 현지 식재료로 이탈리안 요리를 만들어 보고, 자신이 만든 음식을 저녁으로 즐깁니다.
# - **설명**: 요리 클래스에서는 현지 셰프의 지도로 이탈리안 요리를 배우고, 그 과정에서 지역 문화에 대해 더 깊이 이해할 수 있습니다. 저녁이 끝난 후, 자신이 만든 요리를 맛보며 하루를 마무리하는 것은 잊지 못할 경험이 될 것입니다.
#
# 이러한 일정은 토스카나의 매력을 한껏 즐기면서, 자연과 역사, 미식을 동시에 경험할 수 있는 좋은 기회가 될 것입니다. 즐거운 여행 되세요!

# %%
print(final_answer)
# Out:
# 토스카나는 당신이 선호하는 따뜻한 날씨와 아름다운 자연 경관, 그리고 역사적인 장소들을 모두 갖춘 완벽한 여행지입니다! 아래는 하루 동안의 일정을 오전, 오후, 저녁으로 나누어 제안드립니다.
#
# ### 오전
# **피렌체 탐방**
# - **활동**: 피렌체의 주요 명소를 방문합니다. 먼저 **두오모 성당(Duomo)**에 올라가서 도시 전경을 감상하세요. 이후 **우피치 미술관(Uffizi Gallery)**을 찾아가 이탈리아 르네상스 미술의 걸작들을 감상합니다.
# - **설명**: 두오모에서의 전망은 토스카나의 아름다움을 한눈에 담을 수 있는 기회를 제공합니다. 우피치 미술관은 보티첼리, 미켈란젤로 등 유명 화가들의 작품을 소장하고 있어 예술을 좋아하는 당신에게는 흥미로운 경험이 될 것입니다.
#
# ### 오후
# **산 지미냐노 방문 & 포도밭 투어**
# - **활동**: 근교의 중세 도시인 **산 지미냐노(San Gimignano)**를 방문하여 그곳의 역사적인 탑과 구시가지를 산책합니다. 이후 포도밭 투어에 참여하여 다양한 토스카나 와인을 시음합니다.
# - **설명**: 산 지미냐노의 독특한 타워는 중세 시대의 매력을 대표하며, 좁은 골목길을 걷는 것 또한 즐거운 경험이 될 것입니다. 포도밭 투어에서는 현지 와인과 함께 간단한 스낵이 제공되어 미식 경험을 더욱 풍부하게 할 수 있습니다.
#
# ### 저녁
# **요리 클래스**
# - **활동**: 토스카나 전통 요리 클래스를 수강하여 현지 식재료로 이탈리안 요리를 만들어 보고, 자신이 만든 음식을 저녁으로 즐깁니다.
# - **설명**: 요리 클래스에서는 현지 셰프의 지도로 이탈리안 요리를 배우고, 그 과정에서 지역 문화에 대해 더 깊이 이해할 수 있습니다. 저녁이 끝난 후, 자신이 만든 요리를 맛보며 하루를 마무리하는 것은 잊지 못할 경험이 될 것입니다.
#
# 이러한 일정은 토스카나의 매력을 한껏 즐기면서, 자연과 역사, 미식을 동시에 경험할 수 있는 좋은 기회가 될 것입니다. 즐거운 여행 되세요!

# %% [markdown]
# # routing

# %%
def run_router_workflow(user_prompt : str):
    router_prompt = f"""
    사용자의 프롬프트/질문: {user_prompt}

    각 모델은 서로 다른 기능을 가지고 있습니다. 사용자의 질문에 가장 적합한 모델을 선택하세요:
    - gpt-4o: 일반적인 작업에 가장 적합한 모델 (기본값)
    - o1-mini: 코딩 및 복잡한 문제 해결에 적합한 모델
    - gpt-4o-mini: 간단한 사칙연산 등의 작업에 적합한 모델
    
    모델명만 단답형으로 응답하세요
    """
    print(router_prompt)
    selected_model = llm_call(router_prompt)
    print("선택한 모델", selected_model)
    response = llm_call(user_prompt, model = selected_model)
    print(response)
    return response

query1 = "1더하기 2는 뭐지?"
print(query1)
response = run_router_workflow(query1)


query2 = "\n리스본 여행일정을 짜줘"
print(query2)
response = run_router_workflow(query2)


query3 = "\n파이썬으로 API 웹서버를 만들어줘"
print(query3)
response = run_router_workflow(query3)
# Out:
# 1더하기 2는 뭐지?
#
#     사용자의 프롬프트/질문: 1더하기 2는 뭐지?
#
#     각 모델은 서로 다른 기능을 가지고 있습니다. 사용자의 질문에 가장 적합한 모델을 선택하세요:
#     - gpt-4o: 일반적인 작업에 가장 적합한 모델 (기본값)
#     - o1-mini: 코딩 및 복잡한 문제 해결에 적합한 모델
#     - gpt-4o-mini: 간단한 사칙연산 등의 작업에 적합한 모델
#
#     모델명만 단답형으로 응답하세요
#
# 선택한 모델 gpt-4o-mini
# 1 더하기 2는 3입니다.
# 리스본 여행일정을 짜줘
#
#     사용자의 프롬프트/질문: 리스본 여행일정을 짜줘
#
#     각 모델은 서로 다른 기능을 가지고 있습니다. 사용자의 질문에 가장 적합한 모델을 선택하세요:
#     - gpt-4o: 일반적인 작업에 가장 적합한 모델 (기본값)
#     - o1-mini: 코딩 및 복잡한 문제 해결에 적합한 모델
#     - gpt-4o-mini: 간단한 사칙연산 등의 작업에 적합한 모델
#
#     모델명만 단답형으로 응답하세요
#
# 선택한 모델 gpt-4o
# 리스본은 포르투갈의 매력적인 수도로, 다양한 문화와 풍경을 즐길 수 있는 곳입니다. 아래는 3일간의 리스본 여행 일정 예시입니다. 각자의 취향에 따라 수정하여 활용하세요.
#
# ### 1일차: 리스본 탐방
# - **아침**
#   - **벨렘 지구 방문**: 제로니모스 수도원(Jerónimos Monastery)과 벨렘 타워(Torre de Belém)를 방문하세요. 두 곳 모두 유네스코 세계문화유산으로 지정되어 있습니다.
#   - **파스텔 드 벨렘**: 근처의 유명한 'Pastéis de Belém'에서 포르투갈의 전통 에그타르트를 맛보세요.
#
# - **오후**
#   - **리스본 해양 박물관**: 벨렘에 있는 해양 박물관에서 포르투갈의 항해 역사를 만나보세요.
#   - **전차 15E 탑승**: 리스본의 상징적인 전차를 타고 시내로 돌아오세요.
#
# - **저녁**
#   - **알파마 지구 둘러보기**: 리스본의 가장 오래된 지구 중 하나로, 좁은 골목길과 전통적인 분위기를 즐기기에 좋습니다.
#   - **파두 공연 감상**: 알파마에 있는 레스토랑에서 전통 포르투갈 음악인 파두를 들으며 저녁 식사를 즐기세요.
#
# ### 2일차: 문화와 역사 탐방
# - **아침**
#   - **상 조르즈 성(Castelo de São Jorge) 방문**: 리스본의 전경을 감상할 수 있는 성에서 아침을 시작하세요.
#
# - **오후**
#   - **바이샤 지구 탐방**: 리스본의 중심부로, 유명한 코메르시우 광장(Praça do Comércio)과 아우구스타 거리를 걸으며 쇼핑과 식사를 즐길 수 있습니다.
#   - **산타 주스타 엘리베이터(Elevador de Santa Justa)**: 리스본의 독특한 엘리베이터를 타고 전망을 감상하세요.
#
# - **저녁**
#   - **바이루 알투(Bairro Alto) 방문**: 리스본의 활기찬 야경을 즐길 수 있는 지역으로, 다양한 바와 클럽이 있습니다.
#
# ### 3일차: 근교 여행
# - **아침**
#   - **신트라(Sintra) 방문**: 리스본 근교에 위치한 신트라로 이동해 페나 궁전(Palácio Nacional da Pena)과 모우로스 성(Castelo dos Mouros)을 방문하세요.
#
# - **오후**
#   - **카스카이스(Cascais) 해변**: 신트라에서 카스카이스로 이동해 해변에서 여유로운 시간을 보내세요.
#   - **기차를 타고 리스본으로 돌아오기**: 카스카이스에서 리스본으로 돌아가는 기차를 타고 여유롭게 경치를 감상하세요.
#
# - **저녁**
#   - **리베르다데 거리(Avenida da Liberdade)**: 마지막 저녁은 리스본의 쇼핑과 식사를 즐길 수 있는 이곳에서 보내세요.
#
# 이 일정을 참고하여 본인의 취향과 시간에 맞게 조정해보세요. 리스본은 다양한 음식과 문화를 제공하므로 식사 계획도 세밀히 고려해보세요. 즐거운 여행 되세요!
# 파이썬으로 API 웹서버를 만들어줘
#
#     사용자의 프롬프트/질문: 파이썬으로 API 웹서버를 만들어줘
#
#     각 모델은 서로 다른 기능을 가지고 있습니다. 사용자의 질문에 가장 적합한 모델을 선택하세요:
#     - gpt-4o: 일반적인 작업에 가장 적합한 모델 (기본값)
#     - o1-mini: 코딩 및 복잡한 문제 해결에 적합한 모델
#     - gpt-4o-mini: 간단한 사칙연산 등의 작업에 적합한 모델
#
#     모델명만 단답형으로 응답하세요
#
# 선택한 모델 o1-mini
# 파이썬을 사용하여 간단한 API 웹 서버를 만드는 방법을 단계별로 안내해 드리겠습니다. 여기서는 **FastAPI** 프레임워크를 사용하여 효율적이고 현대적인 API 서버를 구축하는 방법을 설명하겠습니다. FastAPI는 속도가 빠르고, 자동 문서화 기능을 제공하며, 비동기 처리를 지원하는 등 여러 장점이 있습니다.
#
# ## 1. 환경 설정
#
# 먼저 파이썬이 설치되어 있는지 확인하세요. Python 3.7 이상이 필요합니다. 터미널 또는 명령 프롬프트에서 아래 명령어로 버전을 확인할 수 있습니다.
#
# ```bash
# python --version
# ```
#
# ## 2. 가상 환경 생성 (권장)
#
# 프로젝트의 의존성을 관리하기 위해 가상 환경을 사용하는 것이 좋습니다.
#
# ```bash
# # 가상 환경 생성
# python -m venv myenv
#
# # 가상 환경 활성화
# # Windows
# myenv\Scripts\activate
#
# # macOS/Linux
# source myenv/bin/activate
# ```
#
# ## 3. 필요한 패키지 설치
#
# FastAPI와 Uvicorn(ASGI 서버)를 설치합니다.
#
# ```bash
# pip install fastapi uvicorn
# ```
#
# ## 4. 간단한 API 서버 작성
#
# 프로젝트 디렉토리에 `main.py` 파일을 생성하고, 아래의 코드를 작성하세요.
#
# ```python
# from fastapi import FastAPI
# from pydantic import BaseModel
#
# app = FastAPI()
#
# # 데이터 모델 정의
# class Item(BaseModel):
#     name: str
#     description: str = None
#     price: float
#     tax: float = None
#
# # 기본 경로
# @app.get("/")
# def read_root():
#     return {"Hello": "World"}
#
# # 경로 매개변수를 사용하는 엔드포인트
# @app.get("/items/{item_id}")
# def read_item(item_id: int, q: str = None):
#     return {"item_id": item_id, "q": q}
#
# # POST 요청을 처리하는 엔드포인트
# @app.post("/items/")
# def create_item(item: Item):
#     return {"name": item.name, "price_with_tax": item.price + (item.tax if item.tax else 0)}
# ```
#
# ### 코드 설명
#
# - **FastAPI 인스턴스 생성**: `app = FastAPI()`를 사용하여 API 애플리케이션을 초기화합니다.
#
# - **데이터 모델 정의**: Pydantic의 `BaseModel`을 상속받아 데이터 모델을 정의합니다. 이는 요청과 응답의 데이터 유효성을 검사하는 데 사용됩니다.
#
# - **엔드포인트 정의**:
#   - `GET /`: 기본 경로로 `"Hello": "World"` 메시지를 반환합니다.
#   - `GET /items/{item_id}`: 아이템 ID와 선택적인 쿼리 파라미터 `q`를 받아서 반환합니다.
#   - `POST /items/`: JSON 형식의 아이템 데이터를 받아 처리하고, 세금이 포함된 가격을 반환합니다.
#
# ## 5. 서버 실행
#
# 터미널에서 다음 명령어를 실행하여 서버를 시작합니다.
#
# ```bash
# uvicorn main:app --reload
# ```
#
# - `main`: Python 파일 이름 (`main.py`).
# - `app`: FastAPI 인스턴스 이름.
# - `--reload`: 코드 변경 시 자동으로 서버를 재시작.
#
# 서버가 성공적으로 실행되면 아래와 같은 메시지가 표시됩니다.
#
# ```
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [pid] using watchgod
# INFO:     Started server process [pid]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ```
#
# ## 6. API 테스트 및 문서화
#
# ### 기본 엔드포인트 테스트
#
# 브라우저나 `curl`을 사용하여 기본 엔드포인트를 테스트할 수 있습니다.
#
# - **GET /**
#
#   ```
#   http://127.0.0.1:8000/
#   ```
#
#   **응답:**
#   ```json
#   {
#     "Hello": "World"
#   }
#   ```
#
# - **GET /items/1?q=test**
#
#   ```
#   http://127.0.0.1:8000/items/1?q=test
#   ```
#
#   **응답:**
#   ```json
#   {
#     "item_id": 1,
#     "q": "test"
#   }
#   ```
#
# ### 자동 문서화
#
# FastAPI는 Swagger UI와 ReDoc을 통해 자동으로 API 문서를 생성합니다.
#
# - **Swagger UI**
#   ```
#   http://127.0.0.1:8000/docs
#   ```
#
# - **ReDoc**
#   ```
#   http://127.0.0.1:8000/redoc
#   ```
#
# 이 페이지들에서 API의 모든 엔드포인트를 시각적으로 확인하고, 직접 테스트할 수도 있습니다.
#
# ### POST 요청 테스트
#
# `POST /items/` 엔드포인트를 테스트하려면 JSON 데이터를 전송해야 합니다. 예를 들어, `curl`을 사용하여 다음과 같이 요청할 수 있습니다.
#
# ```bash
# curl -X POST "http://127.0.0.1:8000/items/" -H "Content-Type: application/json" -d '{"name": "Laptop", "description": "A powerful laptop", "price": 1500.0, "tax": 100.0}'
# ```
#
# **응답:**
# ```json
# {
#   "name": "Laptop",
#   "price_with_tax": 1600.0
# }
# ```
#
# ## 7. 추가 기능 및 배포
#
# FastAPI는 비동기 처리를 지원하고, 데이터베이스와의 연동, 인증 등 다양한 기능을 손쉽게 추가할 수 있습니다. 프로젝트가 완성되면, **Docker**, **Heroku**, **AWS**, **Azure** 등 다양한 플랫폼을 통해 배포할 수 있습니다.
#
# ### 예: 비동기 엔드포인트 추가
#
# ```python
# import asyncio
#
# @app.get("/async")
# async def get_async():
#     await asyncio.sleep(1)  # 비동기 작업 시뮬레이션
#     return {"message": "This was fetched asynchronously"}
# ```
#
# ### 예: 데이터베이스 연동 (SQLite 사용)
#
# `SQLAlchemy`를 사용하여 데이터베이스와 연동할 수 있습니다.
#
# ```bash
# pip install sqlalchemy databases
# ```
#
# 간단한 예제는 FastAPI 공식 문서에서 [데이터베이스 튜토리얼](https://fastapi.tiangolo.com/tutorial/sql-databases/)을 참고하세요.
#
# ## 참고 자료
#
# - [FastAPI 공식 문서](https://fastapi.tiangolo.com/ko/)
# - [FastAPI GitHub 저장소](https://github.com/tiangolo/fastapi)
#
# FastAPI를 사용하면 효율적이고 확장 가능한 API 서버를 쉽게 구축할 수 있습니다. 필요한 기능에 따라 다양한 패키지와 연동하여 프로젝트를 발전시켜 보세요!

# %% [markdown]
# # parallel

# %%
import asyncio

# %%
async def run_llm_parallel(prompt_details):
    tasks = [llm_call_async(prompt['user_prompt'], prompt['model']) for prompt in prompt_details]
    responses = []
    
    for task in asyncio.as_completed(tasks):
        result = await task
        print("LLM 응답 완료:", result)
        responses.append(result)
    
    return responses

# %%
async def main():
    question = ("아래 문장을 자연스러운 한국어로 번역해줘:\n"
                "\"Do what you can, with what you have, where you are.\" — Theodore Roosevelt")
    
    parallel_prompt_details = [
        {"user_prompt": question, "model": "gpt-4o"},
        {"user_prompt": question, "model": "gpt-4o-mini"},
        {"user_prompt": question, "model": "o1-mini"},
    ]
    
    responses = await run_llm_parallel(parallel_prompt_details)
    
    aggregator_prompt = ("다음은 여러 개의 AI 모델이 사용자 질문에 대해 생성한 응답입니다.\n"
                         "당신의 역할은 이 응답들을 모두 종합하여 최종 답변을 제공하는 것입니다.\n"
                         "일부 응답이 부정확하거나 편향될 수 있으므로, 신뢰성과 정확성을 갖춘 응답을 생성하는 것이 중요합니다.\n\n"
                         "사용자 질문:\n"
                         f"{question}\n\n"
                         "모델 응답들:")
    
    for i in range(len(parallel_prompt_details)):
        aggregator_prompt += f"\n{i+1}. 모델 응답: {responses[i]}\n\n"
    
    print("---------------------------종합 프롬프트:-----------------------\n", aggregator_prompt)
    final_response = await llm_call_async(aggregator_prompt, model="gpt-4o")
    print("---------------------------최종 종합 응답:-----------------------\n", final_response)

# %%
await main()
# Out:
# LLM 응답 완료: "당신이 가진 것과 있는 곳에서 가능한 일을 하라." — 시어도어 루즈벨트
# LLM 응답 완료: "당신이 있는 곳에서, 가진 것을 가지고 할 수 있는 일을 하세요." — 시어도어 루즈벨트
# LLM 응답 완료: "할 수 있는 일을, 가진 것들로, 있는 곳에서 하세요." — 시어도어 루스벨트
# ---------------------------종합 프롬프트:-----------------------
#  다음은 여러 개의 AI 모델이 사용자 질문에 대해 생성한 응답입니다.
# 당신의 역할은 이 응답들을 모두 종합하여 최종 답변을 제공하는 것입니다.
# 일부 응답이 부정확하거나 편향될 수 있으므로, 신뢰성과 정확성을 갖춘 응답을 생성하는 것이 중요합니다.
#
# 사용자 질문:
# 아래 문장을 자연스러운 한국어로 번역해줘:
# "Do what you can, with what you have, where you are." — Theodore Roosevelt
#
# 모델 응답들:
# 1. 모델 응답: "당신이 가진 것과 있는 곳에서 가능한 일을 하라." — 시어도어 루즈벨트
#
#
# 2. 모델 응답: "당신이 있는 곳에서, 가진 것을 가지고 할 수 있는 일을 하세요." — 시어도어 루즈벨트
#
#
# 3. 모델 응답: "할 수 있는 일을, 가진 것들로, 있는 곳에서 하세요." — 시어도어 루스벨트
#
#
# ---------------------------최종 종합 응답:-----------------------
#  최종 번역: "당신이 있는 곳에서, 가진 것을 활용하여 할 수 있는 일을 하세요." — 시어도어 루즈벨트

# %% [markdown]
# # orchestrator

# %%
import asyncio
import json

# %%
# 병렬 처리를 위한 함수

async def run_llm_parallel(prompt_list):
    tasks = [llm_call_async(prompt) for prompt in prompt_list]
    responses = []
    
    for task in asyncio.as_completed(tasks):
        result = await task
        responses.append(result)
    return responses

# %%
def get_orchestrator_prompt(user_query):
    # 파이썬 f string에서는 {} 1개는 변수, JSON에서는 2개를 사용해야 함
    
    return f"""
다음 사용자 질문을 분석하고, 이를 3개의 관련된 하위 질문으로 분해하십시오:

다음 형식으로 응답을 제공하십시오:

{{
    "analysis": "사용자 질문에 대한 이해를 상세히 설명하고, 작성한 하위 질문들의 근거를 설명하십시오.",
    "subtasks": [
        {{
            "description": "이 하위 질문의 초점과 의도를 설명하십시오.",
            "sub_question": "질문 1"
        }},
        {{
            "description": "이 하위 질문의 초점과 의도를 설명하십시오.",
            "sub_question": "질문 2"
        }}
        // 필요에 따라 추가 하위 질문 포함
    ]
}}
최대 3개의 하위 질문을 생성하세요

사용자 질문: {user_query}
"""

# %%
def get_worker_prompt(user_query, sub_question, description):
    return f"""
    다음 사용자 질문에서 파생된 하위 질문을 다루는 작업을 맡았습니다:
    원래 질문:  {user_query}
    하위 질문: {sub_question}

    지침: {description}

    하위 질문을 철저히 다루는 포괄적이고 상세한 응답을 해주세요
    """

# %%
user_query = "AI는 미래 일자리에 어떤 영향을 미칠까?"

# %%
async def orchestrate_task(user_query):
    """
    오케스트레이터를 실행하여 원래 질문을 하위 질문으로 분해하고,
    각각의 하위 질문을 병렬적으로 실행하여 종합적인 응답을 생성합니다.
    """

    # 1단계 : 사용자 질문 기반으로 여러 질문 도출
    orchestrator_prompt = get_orchestrator_prompt(user_query)
    print("\n============================orchestrator prompt============================\n")
    print(orchestrator_prompt)
    orchestrator_response = llm_call(orchestrator_prompt, model="gpt-4o")
 
    # 응답 결과 (1단계) 출력
    print("\n============================orchestrator response==========================\n")
    print(orchestrator_response)
 
    response_json = json.loads(orchestrator_response.replace('```json', '').replace('```', ''))
    
    analysis = response_json.get("analysis", "")
    sub_tasks = response_json.get("subtasks", [])

    # 2단계 : 각 하위질문에 대한 LLM 호출
    worker_prompts = [get_worker_prompt(user_query, task["sub_question"], task["description"]) for task in sub_tasks]
    print("\n============================worker prompts==========================\n")
    for prompt in worker_prompts:
        print(prompt)

    worker_responses = await run_llm_parallel(worker_prompts)
    
    # 응답결과(2단계) 출력
    print("\n============================worker responses==========================\n")
    for response in worker_responses:
        print(response) 
    
    # 3단계 : 하위질문 응답 종합 및 LLM 호출
    aggregator_prompt = f"""아래는 사용자의 원래 질문에 대해서 하위 질문을 나누고 응답한 결과입니다.
    아래 질문 및 응답내용을 포함한 최종 응답을 제공해주세요.
    ## 요청사항
    - 하위질문 응답내용이 최대한 포괄적이고 상세하게 포함되어야 합니다
    사용자의 원래 질문:
    {user_query}

    하위 질문 및 응답:
    """
    
    for i in range(len(sub_tasks)):
        aggregator_prompt += f"\n{i+1}. 하위 질문: {sub_tasks[i]['sub_question']}\n"
        aggregator_prompt += f"\n   응답: {worker_responses[i]}\n"
    
    print("\n============================aggregator prompt==========================\n")
    print(aggregator_prompt)
    
    final_response = llm_call(aggregator_prompt, model="gpt-4o")
    
    return final_response

# %%
user_query = "AI는 미래 일자리에 어떤 영향을 미칠까?"
final_output = await orchestrate_task(user_query)
# Out:
# ============================orchestrator prompt============================
#
#
# 다음 사용자 질문을 분석하고, 이를 3개의 관련된 하위 질문으로 분해하십시오:
#
# 다음 형식으로 응답을 제공하십시오:
#
# {
#     "analysis": "사용자 질문에 대한 이해를 상세히 설명하고, 작성한 하위 질문들의 근거를 설명하십시오.",
#     "subtasks": [
#         {
#             "description": "이 하위 질문의 초점과 의도를 설명하십시오.",
#             "sub_question": "질문 1"
#         },
#         {
#             "description": "이 하위 질문의 초점과 의도를 설명하십시오.",
#             "sub_question": "질문 2"
#         }
#         // 필요에 따라 추가 하위 질문 포함
#     ]
# }
# 최대 3개의 하위 질문을 생성하세요
#
# 사용자 질문: AI는 미래 일자리에 어떤 영향을 미칠까?
#
#
# ============================orchestrator response==========================
#
# ```json
# {
#     "analysis": "사용자 질문은 AI가 미래의 일자리 시장에 미치는 잠재적 영향을 탐구하려고 합니다. AI 기술의 발전은 다양한 산업에서 자동화와 새로운 형태의 직무 및 일자리를 가져올 수 있습니다. 이를 더 잘 이해하기 위해 AI가 일자리의 종류, 업무 방식, 고용 시장의 구조 등에 미치는 영향을 세부적으로 살펴볼 필요가 있습니다.",
#     "subtasks": [
#         {
#             "description": "AI가 자동화와 새로운 기술을 통해 기존 일자리의 성격과 구조를 어떻게 변화시킬지를 탐구합니다.",
#             "sub_question": "AI 기술의 발전이 기존의 일자리와 직무의 자동화에 어떤 영향을 미치게 될까요?"
#         },
#         {
#             "description": "AI로 인해 생성되는 새로운 형태의 직업과 산업 기회에 초점을 맞춥니다.",
#             "sub_question": "AI의 발전으로 인해 어떤 새로운 일자리와 산업이 생겨날 가능성이 있나요?"
#         },
#         {
#             "description": "AI가 노동 시장의 구조와 고용 형태, 근무 환경에 미치는 영향을 분석합니다.",
#             "sub_question": "AI 도입으로 인해 고용 시장 및 근무 환경은 어떻게 변화할 것으로 예상되나요?"
#         }
#     ]
# }
# ```
#
# ============================worker prompts==========================
#
#
#     다음 사용자 질문에서 파생된 하위 질문을 다루는 작업을 맡았습니다:
#     원래 질문:  AI는 미래 일자리에 어떤 영향을 미칠까?
#     하위 질문: AI 기술의 발전이 기존의 일자리와 직무의 자동화에 어떤 영향을 미치게 될까요?
#
#     지침: AI가 자동화와 새로운 기술을 통해 기존 일자리의 성격과 구조를 어떻게 변화시킬지를 탐구합니다.
#
#     하위 질문을 철저히 다루는 포괄적이고 상세한 응답을 해주세요
#
#
#     다음 사용자 질문에서 파생된 하위 질문을 다루는 작업을 맡았습니다:
#     원래 질문:  AI는 미래 일자리에 어떤 영향을 미칠까?
#     하위 질문: AI의 발전으로 인해 어떤 새로운 일자리와 산업이 생겨날 가능성이 있나요?
#
#     지침: AI로 인해 생성되는 새로운 형태의 직업과 산업 기회에 초점을 맞춥니다.
#
#     하위 질문을 철저히 다루는 포괄적이고 상세한 응답을 해주세요
#
#
#     다음 사용자 질문에서 파생된 하위 질문을 다루는 작업을 맡았습니다:
#     원래 질문:  AI는 미래 일자리에 어떤 영향을 미칠까?
#     하위 질문: AI 도입으로 인해 고용 시장 및 근무 환경은 어떻게 변화할 것으로 예상되나요?
#
#     지침: AI가 노동 시장의 구조와 고용 형태, 근무 환경에 미치는 영향을 분석합니다.
#
#     하위 질문을 철저히 다루는 포괄적이고 상세한 응답을 해주세요
#
#
# ============================worker responses==========================
#
# AI의 도입은 노동 시장과 근무 환경에 많은 변화를 초래할 것으로 예상됩니다. 이러한 변화는 주로 기술 발전과 자동화의 진전으로 인해 발생하며, 다음과 같은 여러 측면에서 분석할 수 있습니다.
#
# ### 1. 고용 시장의 구조 변화
#
# #### a. 일자리의 창출 및 소멸
# AI와 자동화 기술의 도입은 특정 직종의 일자리를 대체할 수 있지만, 동시에 새로운 직종을 창출할 가능성도 큽니다. 예를 들어, 반복적이고 규칙적인 작업을 수행하는 직종은 AI가 대체할 수 있어 일자리가 줄어들 수 있지만, 데이터 과학자, AI 개발자, 머신러닝 엔지니어와 같은 새로운 직업이 생겨날 것입니다.
#
# #### b. 산업 간 이동
# AI 도입으로 인해 일부 산업에서 일자리가 감소하는 반면, 기술 중심의 산업에서는 증가하는 경향이 나타납니다. 이는 노동 시장 구조를 변화시켜, 특정 기술에 대한 수요가 높아질 것으로 보이며, 노동자들은 이러한 변화에 적응하기 위해 새로운 기술을 배워야 할 필요성이 커질 것입니다.
#
# ### 2. 고용 형태의 변화
#
# #### a. 비정규직 및 프리랜서 증가
# AI 기술의 발전으로 인해 기업들이 자동화된 시스템을 활용하여 비용 효율성을 높이면서, 고용 형태가 기존의 정규직 중심에서 비정규직, 프리랜서, 임시직 등으로 변화할 가능성이 큽니다. 이는 특히 IT와 관련된 업종에서 더욱 두드러지게 나타날 것입니다.
#
# #### b. 원격 근무의 확산
# AI 기술은 원격 근무를 더욱 쉽게 만들어 각종 소통, 협업 도구의 발전과 함께, 근무 환경이 물리적 공간에 제한되지 않는 방향으로 변화할 것입니다. 이는 시간과 장소에 구애받지 않는 근무 환경을 제공하여 더욱 유연한 근무 형태를 가능하게 합니다.
#
# ### 3. 근무 환경의 변화
#
# #### a. 스마트 오피스
# AI와 IoT(사물인터넷) 기술의 결합은 스마트 오피스를 가능하게 하여 더 효율적이고 쾌적한 근무 환경을 제공할 것입니다. 이러한 오피스는 작업자의 필요와 선호에 맞춘 개인화된 공간을 제공하여 생산성을 극대화할 수 있습니다.
#
# #### b. 직무의 변화
# AI의 도입은 단순 업무의 자동화를 가져오지만, 동시에 상위 직무에서의 의사결정, 창의력, 해결 능력과 같은 인간의 고유한 능력을 더욱 중요하게 할 것입니다. 이는 근무 환경에서 직무의 성격이 변화하게 하고, 고급 기술이나 소프트 스킬이 더욱 요구되는 경향으로 이어질 것입니다.
#
# ### 4. 교육 및 훈련의 중요성 증가
# AI가 노동 시장에 미치는 영향에 대응하기 위해, 교육과 훈련의 중요성이 더욱 강조됩니다. 기존의 고용주들은 직원들이 필요한 기술을 습득하도록 지원해야 하며, 사람들은 지속적으로 학습해야 하는 환경이 조성될 것입니다. 이는 생애 전반에 걸쳐 학습이 이루어지는 문화로 이어질 가능성이 큽니다.
#
# ### 5. 사회적 영향
# AI의 도입으로 인해 소외된 계층이 발생할 수 있으며, 이는 사회적 불평등을 더욱 심화시킬 우려가 있습니다. 따라서 정부와 기업 차원에서의 지원 정책이 필요하며, 재교육 프로그램 및 노동 시장의 유연성을 높이는 정책이 중요할 것입니다.
#
# ### 결론
# AI 기술의 도입은 고용 시장과 근무 환경에 다양한 변화를 가져올 것입니다. 이는 일자리의 구조 변화, 고용 형태의 다양화, 직무의 변화, 그리고 새로운 교육 필요성을 포함하여 전반적인 노동 시장의 패러다임을 변화시키는 요소로 작용합니다. 이러한 변화에 적절히 대응하기 위해 기업, 정부, 그리고 개인의 협력이 필요하며, 혁신적인 해결책과 정책이 마련되어야 할 것입니다.
# AI 기술의 발전은 기존 일자리와 직무의 자동화에 상당한 영향을 미칠 것으로 예상됩니다. 이러한 변화는 여러 면에서 나타나며, 직무의 성격과 구조를 변화시키는 여러 요소를 포함합니다. 다음은 AI가 기존 일자리와 직무에 미치는 영향에 대한 포괄적인 분석입니다.
#
# ### 1. **자동화의 원동력**
# AI 기술은 반복적이고 규칙 기반의 업무를 효율적으로 수행할 수 있습니다. 예를 들어, 제조업, 물류, 고객 서비스 등에서 AI와 로봇 프로세스 자동화(RPA)가 기존의 인간 노동력을 대체할 수 있습니다. 이는 생산성을 높이고 비용을 절감하는 동시에, 불량률을 줄이는 효과를 가져옵니다.
#
# ### 2. **직무의 변화**
# AI의 도입으로 기존 직무의 성격이 변화하게 됩니다. 단순히 특정 작업을 수행하는 역할에서, 데이터 분석, 의사결정 지원, 창의적 아이디어 발굴 등의 고차원적 업무로 변화할 수 있습니다. 예를 들어, 회계 분야에서는 AI가 자동으로 거래를 기록하고 분석할 수 있어 회계사들은 더 복잡한 재무 전략이나 분석에 집중할 수 있게 됩니다.
#
# ### 3. **직업의 재구성**
# 일부 직업은 AI 기술의 발전으로 인해 사라지거나 형태가 변할 수 있습니다. 예를 들어, 택시기사, 제조업 노동자, 전화 상담원 등은 AI에 의해 대체될 가능성이 큽니다. 그러나 이러한 변화는 새로운 직업의 출현도 동반합니다. AI 전문가, 데이터 과학자, 윤리적 AI 관리자, 로봇 기술자 등 다양한 신직종이 등장할 것으로 보입니다.
#
# ### 4. **기술 스킬의 요구 증가**
# AI와 자동화의 발전은 직원들이 갖추어야 할 기술 스킬의 요구를 높입니다. 이제는 기계와 협력하고, 데이터를 분석하며, AI 도구를 활용할 줄 아는 능력이 필수적입니다. 따라서, 기업은 직원들에게 재교육과 지속적인 학습 기회를 제공해야 하며, 이는 직장 내 교육 프로그램의 확대를 의미합니다.
#
# ### 5. **사회적 및 경제적 영향**
# AI의 자동화로 인해 특정 산업에 종사하는 근로자들은 일자리 상실이라는 불안에 직면할 수 있습니다. 이는 사회적 불평등을 심화시킬 수 있으며, 정부와 기업은 이런 이슈를 해결하기 위한 정책과 프로그램을 마련해야 합니다. 예를 들어, 전직 지원 프로그램, 기본소득 제도, 기술적 재교육 등이 고려될 수 있습니다.
#
# ### 6. **AI와 인간의 협업**
# AI는 전체적으로 인간과 기계 간의 협업을 촉진할 것입니다. 예를 들어, 의료 분야에서는 AI가 진단 지원 시스템을 통해 의사들의 결정을 보조하는 형태로 활용될 수 있습니다. 이와 같은 협업은 직무의 질을 높이고, 인적 자원의 효율성을 극대화할 수 있는 가능성을 제공합니다.
#
# ### 7. **윤리적 고려사항**
# AI의 자동화가 진행됨에 따라 윤리적 문제도 제기됩니다. 예를 들어, 자동화된 업무의 공정성과 투명성이 문제될 수 있으며, AI의 결정에 대한 책임 소재도 중요합니다. 이런 윤리적 고려는 기업의 정책과 사회 전반에 걸쳐 논의되어야 합니다.
#
# ### 결론
# AI 기술의 발전은 기존의 일자리와 직무의 자동화에 커다란 영향을 미치며, 이는 직무의 성격, 규모, 필요 기술의 변화를 초래합니다. 이러한 변화는 일자리의 감소와 새로운 일자리의 창출, 기술 스킬의 재조정, 사회적 불평등 문제 등 다양한 과제를 동반합니다. 따라서 기업과 정부는 이에 대한 신중한 접근과 준비가 필요합니다. AI와 자동화의 영향력을 이해하고, 이와 같은 변화에 적응할 수 있는 능력을 기르는 것이 앞으로의 고용 시장에 매우 중요할 것입니다.
# AI의 발전은 현재와 미래의 직업 시장에 커다란 변화를 가져오고 있으며, 이로 인해 새로운 일자리와 산업이 등장할 가능성이 큽니다. 이러한 변화는 기술, 경제, 사회적 맥락에 따라 다양한 방식으로 이루어질 것입니다. 아래에서 AI의 발전이 야기할 새로운 형태의 직업과 산업 기회를 상세히 살펴보겠습니다.
#
# ### 1. AI 개발 및 관리 관련 직업
#
# AI 기술의 발전에 따라 AI 모델을 개발하고 운영하는 전문 인력에 대한 수요가 증가하고 있습니다. 구체적인 직업에는 다음이 포함됩니다.
#
# - **AI 연구원**: 인공지능의 기본 이론과 알고리즘을 연구하는 직업으로, 기계 학습, 딥러닝 등의 분야에서 활발히 활동합니다.
# - **데이터 과학자**: 대량의 데이터를 분석하고 AI 모델을 최적화하기 위한 인사이트를 제공하는 역할을 합니다.
# - **AI 윤리 전문가**: AI 사용의 윤리적 문제를 다루고, 법률 및 규제를 준수하는 방향으로 기술이 발전할 수 있도록 안내합니다.
#
# ### 2. AI에 기반한 새로운 산업의 발전
#
# AI는 특정 산업을 혁신하고 새로운 산업을 창출하는 데 중요한 역할을 합니다. 예를 들어:
#
# - **헬스케어**: AI는 진단 지원 시스템, 환자 모니터링 솔루션, 약물 개발 등에서 활용되며, 이에 관련된 직책들이 늘어나고 있습니다. AI 헬스케어 애널리스트, 의료 데이터 관리 전문가 등이 이에 해당합니다.
# - **자동화된 운송**: 자율주행차와 드론의 도입으로 자동차 및 물류 산업에서 새로운 일자리가 창출될 것입니다. 여기에 기술 유지 보수 직원 및 자율 주행 시스템 엔지니어가 포함됩니다.
# - **스마트 제조**: 제조업에서 AI의 도입으로 스마트 팩토리, 로봇 공정 자동화 관련 직업이 생겨난다. 이는 공정 엔지니어와 로봇 프로그래머 같은 역할을 포함합니다.
#
# ### 3. 인간과 AI의 협업을 위한 직업
#
# AI와 협업하는 형태의 새로운 직업이 나타날 것입니다. 예를 들면:
#
# - **AI 트레이너 또는 소도구 애널리스트**: AI 시스템을 교육하고 개선하는 역할로, 인간의 경험과 무감각한 AI 시스템 간의 협력을 최적화합니다.
# - **AI 고객 지원 전문가**: AI 챗봇이나 가상 비서 등을 관리하며, 고객 서비스 전반에 걸쳐 AI를 효율적으로 활용하고 지원하는 직무입니다.
#
# ### 4. 창의적 산업의 변화
#
# AI는 예술, 음악, 콘텐츠 생성 등 창의적인 분야에서도 새로운 기회를 제공합니다.
#
# - **AI 아티스트**: 알고리즘을 통해 새로운 형태의 예술 작품을 창조하는 아티스트로, AI와 협력하여 예술적 내러티브를 탐색합니다.
# - **콘텐츠 생성 도구 개발자**: AI를 활용한 콘텐츠 생성 소프트웨어를 개발하고 이를 운영하며 콘텐츠 생산 프로세스를 혁신하는 직업입니다.
#
# ### 5. 지속 가능한 기술 및 환경 관련 일자리
#
# AI는 환경 보호와 지속 가능한 개발을 위한 혁신적인 기술들에도 활용되고 있습니다.
#
# - **스마트 에너지 관리 전문가**: AI를 통해 에너지 사용을 최적화하고, 환경 친화적인 기술을 채택하는 역할을 수행합니다.
# - **AI 기반 환경 모니터링 전문가**: AI를 사용하여 기후 변화나 환경 오염을 모니터링하고 분석하는 전문 인력입니다.
#
# ### 결론
#
# AI의 발전은 단순히 기존 일자리를 대체하는 것이 아니라, 새로운 직업과 산업을 창출하는 기회로 작용할 것입니다. 복잡한 기술적 요구를 충족할 수 있는 인재와 AI와 협업할 수 있는 능력을 갖춘 인력이 점점 더 중요해질 것입니다. 따라서 교육과 재훈련을 통해 이러한 새로운 기회에 대비하는 것이 필요합니다. AI의 발전이 가져올 직업의 변화는 앞으로의 경제적, 사회적 환경에 중대한 영향을 미칠 것입니다.
#
# ============================aggregator prompt==========================
#
# 아래는 사용자의 원래 질문에 대해서 하위 질문을 나누고 응답한 결과입니다.
#     아래 질문 및 응답내용을 포함한 최종 응답을 제공해주세요.
#     ## 요청사항
#     - 하위질문 응답내용이 최대한 포괄적이고 상세하게 포함되어야 합니다
#     사용자의 원래 질문:
#     AI는 미래 일자리에 어떤 영향을 미칠까?
#
#     하위 질문 및 응답:
#
# 1. 하위 질문: AI 기술의 발전이 기존의 일자리와 직무의 자동화에 어떤 영향을 미치게 될까요?
#
#    응답: AI의 도입은 노동 시장과 근무 환경에 많은 변화를 초래할 것으로 예상됩니다. 이러한 변화는 주로 기술 발전과 자동화의 진전으로 인해 발생하며, 다음과 같은 여러 측면에서 분석할 수 있습니다.
#
# ### 1. 고용 시장의 구조 변화
#
# #### a. 일자리의 창출 및 소멸
# AI와 자동화 기술의 도입은 특정 직종의 일자리를 대체할 수 있지만, 동시에 새로운 직종을 창출할 가능성도 큽니다. 예를 들어, 반복적이고 규칙적인 작업을 수행하는 직종은 AI가 대체할 수 있어 일자리가 줄어들 수 있지만, 데이터 과학자, AI 개발자, 머신러닝 엔지니어와 같은 새로운 직업이 생겨날 것입니다.
#
# #### b. 산업 간 이동
# AI 도입으로 인해 일부 산업에서 일자리가 감소하는 반면, 기술 중심의 산업에서는 증가하는 경향이 나타납니다. 이는 노동 시장 구조를 변화시켜, 특정 기술에 대한 수요가 높아질 것으로 보이며, 노동자들은 이러한 변화에 적응하기 위해 새로운 기술을 배워야 할 필요성이 커질 것입니다.
#
# ### 2. 고용 형태의 변화
#
# #### a. 비정규직 및 프리랜서 증가
# AI 기술의 발전으로 인해 기업들이 자동화된 시스템을 활용하여 비용 효율성을 높이면서, 고용 형태가 기존의 정규직 중심에서 비정규직, 프리랜서, 임시직 등으로 변화할 가능성이 큽니다. 이는 특히 IT와 관련된 업종에서 더욱 두드러지게 나타날 것입니다.
#
# #### b. 원격 근무의 확산
# AI 기술은 원격 근무를 더욱 쉽게 만들어 각종 소통, 협업 도구의 발전과 함께, 근무 환경이 물리적 공간에 제한되지 않는 방향으로 변화할 것입니다. 이는 시간과 장소에 구애받지 않는 근무 환경을 제공하여 더욱 유연한 근무 형태를 가능하게 합니다.
#
# ### 3. 근무 환경의 변화
#
# #### a. 스마트 오피스
# AI와 IoT(사물인터넷) 기술의 결합은 스마트 오피스를 가능하게 하여 더 효율적이고 쾌적한 근무 환경을 제공할 것입니다. 이러한 오피스는 작업자의 필요와 선호에 맞춘 개인화된 공간을 제공하여 생산성을 극대화할 수 있습니다.
#
# #### b. 직무의 변화
# AI의 도입은 단순 업무의 자동화를 가져오지만, 동시에 상위 직무에서의 의사결정, 창의력, 해결 능력과 같은 인간의 고유한 능력을 더욱 중요하게 할 것입니다. 이는 근무 환경에서 직무의 성격이 변화하게 하고, 고급 기술이나 소프트 스킬이 더욱 요구되는 경향으로 이어질 것입니다.
#
# ### 4. 교육 및 훈련의 중요성 증가
# AI가 노동 시장에 미치는 영향에 대응하기 위해, 교육과 훈련의 중요성이 더욱 강조됩니다. 기존의 고용주들은 직원들이 필요한 기술을 습득하도록 지원해야 하며, 사람들은 지속적으로 학습해야 하는 환경이 조성될 것입니다. 이는 생애 전반에 걸쳐 학습이 이루어지는 문화로 이어질 가능성이 큽니다.
#
# ### 5. 사회적 영향
# AI의 도입으로 인해 소외된 계층이 발생할 수 있으며, 이는 사회적 불평등을 더욱 심화시킬 우려가 있습니다. 따라서 정부와 기업 차원에서의 지원 정책이 필요하며, 재교육 프로그램 및 노동 시장의 유연성을 높이는 정책이 중요할 것입니다.
#
# ### 결론
# AI 기술의 도입은 고용 시장과 근무 환경에 다양한 변화를 가져올 것입니다. 이는 일자리의 구조 변화, 고용 형태의 다양화, 직무의 변화, 그리고 새로운 교육 필요성을 포함하여 전반적인 노동 시장의 패러다임을 변화시키는 요소로 작용합니다. 이러한 변화에 적절히 대응하기 위해 기업, 정부, 그리고 개인의 협력이 필요하며, 혁신적인 해결책과 정책이 마련되어야 할 것입니다.
#
# 2. 하위 질문: AI의 발전으로 인해 어떤 새로운 일자리와 산업이 생겨날 가능성이 있나요?
#
#    응답: AI 기술의 발전은 기존 일자리와 직무의 자동화에 상당한 영향을 미칠 것으로 예상됩니다. 이러한 변화는 여러 면에서 나타나며, 직무의 성격과 구조를 변화시키는 여러 요소를 포함합니다. 다음은 AI가 기존 일자리와 직무에 미치는 영향에 대한 포괄적인 분석입니다.
#
# ### 1. **자동화의 원동력**
# AI 기술은 반복적이고 규칙 기반의 업무를 효율적으로 수행할 수 있습니다. 예를 들어, 제조업, 물류, 고객 서비스 등에서 AI와 로봇 프로세스 자동화(RPA)가 기존의 인간 노동력을 대체할 수 있습니다. 이는 생산성을 높이고 비용을 절감하는 동시에, 불량률을 줄이는 효과를 가져옵니다.
#
# ### 2. **직무의 변화**
# AI의 도입으로 기존 직무의 성격이 변화하게 됩니다. 단순히 특정 작업을 수행하는 역할에서, 데이터 분석, 의사결정 지원, 창의적 아이디어 발굴 등의 고차원적 업무로 변화할 수 있습니다. 예를 들어, 회계 분야에서는 AI가 자동으로 거래를 기록하고 분석할 수 있어 회계사들은 더 복잡한 재무 전략이나 분석에 집중할 수 있게 됩니다.
#
# ### 3. **직업의 재구성**
# 일부 직업은 AI 기술의 발전으로 인해 사라지거나 형태가 변할 수 있습니다. 예를 들어, 택시기사, 제조업 노동자, 전화 상담원 등은 AI에 의해 대체될 가능성이 큽니다. 그러나 이러한 변화는 새로운 직업의 출현도 동반합니다. AI 전문가, 데이터 과학자, 윤리적 AI 관리자, 로봇 기술자 등 다양한 신직종이 등장할 것으로 보입니다.
#
# ### 4. **기술 스킬의 요구 증가**
# AI와 자동화의 발전은 직원들이 갖추어야 할 기술 스킬의 요구를 높입니다. 이제는 기계와 협력하고, 데이터를 분석하며, AI 도구를 활용할 줄 아는 능력이 필수적입니다. 따라서, 기업은 직원들에게 재교육과 지속적인 학습 기회를 제공해야 하며, 이는 직장 내 교육 프로그램의 확대를 의미합니다.
#
# ### 5. **사회적 및 경제적 영향**
# AI의 자동화로 인해 특정 산업에 종사하는 근로자들은 일자리 상실이라는 불안에 직면할 수 있습니다. 이는 사회적 불평등을 심화시킬 수 있으며, 정부와 기업은 이런 이슈를 해결하기 위한 정책과 프로그램을 마련해야 합니다. 예를 들어, 전직 지원 프로그램, 기본소득 제도, 기술적 재교육 등이 고려될 수 있습니다.
#
# ### 6. **AI와 인간의 협업**
# AI는 전체적으로 인간과 기계 간의 협업을 촉진할 것입니다. 예를 들어, 의료 분야에서는 AI가 진단 지원 시스템을 통해 의사들의 결정을 보조하는 형태로 활용될 수 있습니다. 이와 같은 협업은 직무의 질을 높이고, 인적 자원의 효율성을 극대화할 수 있는 가능성을 제공합니다.
#
# ### 7. **윤리적 고려사항**
# AI의 자동화가 진행됨에 따라 윤리적 문제도 제기됩니다. 예를 들어, 자동화된 업무의 공정성과 투명성이 문제될 수 있으며, AI의 결정에 대한 책임 소재도 중요합니다. 이런 윤리적 고려는 기업의 정책과 사회 전반에 걸쳐 논의되어야 합니다.
#
# ### 결론
# AI 기술의 발전은 기존의 일자리와 직무의 자동화에 커다란 영향을 미치며, 이는 직무의 성격, 규모, 필요 기술의 변화를 초래합니다. 이러한 변화는 일자리의 감소와 새로운 일자리의 창출, 기술 스킬의 재조정, 사회적 불평등 문제 등 다양한 과제를 동반합니다. 따라서 기업과 정부는 이에 대한 신중한 접근과 준비가 필요합니다. AI와 자동화의 영향력을 이해하고, 이와 같은 변화에 적응할 수 있는 능력을 기르는 것이 앞으로의 고용 시장에 매우 중요할 것입니다.
#
# 3. 하위 질문: AI 도입으로 인해 고용 시장 및 근무 환경은 어떻게 변화할 것으로 예상되나요?
#
#    응답: AI의 발전은 현재와 미래의 직업 시장에 커다란 변화를 가져오고 있으며, 이로 인해 새로운 일자리와 산업이 등장할 가능성이 큽니다. 이러한 변화는 기술, 경제, 사회적 맥락에 따라 다양한 방식으로 이루어질 것입니다. 아래에서 AI의 발전이 야기할 새로운 형태의 직업과 산업 기회를 상세히 살펴보겠습니다.
#
# ### 1. AI 개발 및 관리 관련 직업
#
# AI 기술의 발전에 따라 AI 모델을 개발하고 운영하는 전문 인력에 대한 수요가 증가하고 있습니다. 구체적인 직업에는 다음이 포함됩니다.
#
# - **AI 연구원**: 인공지능의 기본 이론과 알고리즘을 연구하는 직업으로, 기계 학습, 딥러닝 등의 분야에서 활발히 활동합니다.
# - **데이터 과학자**: 대량의 데이터를 분석하고 AI 모델을 최적화하기 위한 인사이트를 제공하는 역할을 합니다.
# - **AI 윤리 전문가**: AI 사용의 윤리적 문제를 다루고, 법률 및 규제를 준수하는 방향으로 기술이 발전할 수 있도록 안내합니다.
#
# ### 2. AI에 기반한 새로운 산업의 발전
#
# AI는 특정 산업을 혁신하고 새로운 산업을 창출하는 데 중요한 역할을 합니다. 예를 들어:
#
# - **헬스케어**: AI는 진단 지원 시스템, 환자 모니터링 솔루션, 약물 개발 등에서 활용되며, 이에 관련된 직책들이 늘어나고 있습니다. AI 헬스케어 애널리스트, 의료 데이터 관리 전문가 등이 이에 해당합니다.
# - **자동화된 운송**: 자율주행차와 드론의 도입으로 자동차 및 물류 산업에서 새로운 일자리가 창출될 것입니다. 여기에 기술 유지 보수 직원 및 자율 주행 시스템 엔지니어가 포함됩니다.
# - **스마트 제조**: 제조업에서 AI의 도입으로 스마트 팩토리, 로봇 공정 자동화 관련 직업이 생겨난다. 이는 공정 엔지니어와 로봇 프로그래머 같은 역할을 포함합니다.
#
# ### 3. 인간과 AI의 협업을 위한 직업
#
# AI와 협업하는 형태의 새로운 직업이 나타날 것입니다. 예를 들면:
#
# - **AI 트레이너 또는 소도구 애널리스트**: AI 시스템을 교육하고 개선하는 역할로, 인간의 경험과 무감각한 AI 시스템 간의 협력을 최적화합니다.
# - **AI 고객 지원 전문가**: AI 챗봇이나 가상 비서 등을 관리하며, 고객 서비스 전반에 걸쳐 AI를 효율적으로 활용하고 지원하는 직무입니다.
#
# ### 4. 창의적 산업의 변화
#
# AI는 예술, 음악, 콘텐츠 생성 등 창의적인 분야에서도 새로운 기회를 제공합니다.
#
# - **AI 아티스트**: 알고리즘을 통해 새로운 형태의 예술 작품을 창조하는 아티스트로, AI와 협력하여 예술적 내러티브를 탐색합니다.
# - **콘텐츠 생성 도구 개발자**: AI를 활용한 콘텐츠 생성 소프트웨어를 개발하고 이를 운영하며 콘텐츠 생산 프로세스를 혁신하는 직업입니다.
#
# ### 5. 지속 가능한 기술 및 환경 관련 일자리
#
# AI는 환경 보호와 지속 가능한 개발을 위한 혁신적인 기술들에도 활용되고 있습니다.
#
# - **스마트 에너지 관리 전문가**: AI를 통해 에너지 사용을 최적화하고, 환경 친화적인 기술을 채택하는 역할을 수행합니다.
# - **AI 기반 환경 모니터링 전문가**: AI를 사용하여 기후 변화나 환경 오염을 모니터링하고 분석하는 전문 인력입니다.
#
# ### 결론
#
# AI의 발전은 단순히 기존 일자리를 대체하는 것이 아니라, 새로운 직업과 산업을 창출하는 기회로 작용할 것입니다. 복잡한 기술적 요구를 충족할 수 있는 인재와 AI와 협업할 수 있는 능력을 갖춘 인력이 점점 더 중요해질 것입니다. 따라서 교육과 재훈련을 통해 이러한 새로운 기회에 대비하는 것이 필요합니다. AI의 발전이 가져올 직업의 변화는 앞으로의 경제적, 사회적 환경에 중대한 영향을 미칠 것입니다.

# %% [markdown]
# # evaluator - optimizer

# %%
def loop_workflow(user_query, evaluator_prompt, max_retries=5) -> str:
    """평가자가 생성된 요약을 통과할 때까지 최대 max_retries번 반복."""

    retries = 0
    while retries < max_retries:
        print(f"\n========== 📝 요약 프롬프트 (시도 {retries + 1}/{max_retries}) ==========\n")
        print(user_query)
        
        summary = llm_call(user_query, model="gpt-4o-mini")
        print(f"\n========== 📝 요약 결과 (시도 {retries + 1}/{max_retries}) ==========\n")
        print(summary)
        
        final_evaluator_prompt = evaluator_prompt + summary
        evaluation_result = llm_call(final_evaluator_prompt, model="gpt-4o").strip()

        print(f"\n========== 🔍 평가 프롬프트 (시도 {retries + 1}/{max_retries}) ==========\n")
        print(final_evaluator_prompt)

        print(f"\n========== 🔍 평가 결과 (시도 {retries + 1}/{max_retries}) ==========\n")
        print(evaluation_result)

        if "평가결과 = PASS" in evaluation_result:
            print("\n✅ 통과! 최종 요약이 승인되었습니다.\n")
            return summary
        
        retries += 1
        print(f"\n🔄 재시도 필요... ({retries}/{max_retries})\n")

        # If max retries reached, return last attempt
        if retries >= max_retries:
            print("❌ 최대 재시도 횟수 도달. 마지막 요약을 반환합니다.")
            return summary  # Returning the last attempted summary, even if it's not perfect.

        # Updating the user_query for the next attempt with full history
        user_query += f"{retries}차 요약 결과:\n\n{summary}\n"
        user_query += f"{retries}차 요약 피드백:\n\n{evaluation_result}\n\n"

def main():
    ## 기사 링크 : https://zdnet.co.kr/view/?no=20250213091248
    input_article = """
오픈AI가 몇 주 안에 새로운 모델인 'GPT-4.5'를 출시하며 분산돼 있던 생성형 인공지능(AI) 모델을 통합키로 했다. 추론용 모델인 'o' 시리즈를 정리하고 비(非)추론 모델인 'GPT' 시리즈로 합칠 예정이다.

13일 업계에 따르면 샘 알트먼 오픈AI 최고경영자(CEO)는 지난 12일 자신의 X(옛 트위터)에 'GPT-4.5'를 조만간 출시할 것이라고 밝혔다. 현 세대인 'GPT-4o'의 뒤를 잇는 마지막 '비추론 AI'로, 내부적으로는 '오라이언(Orion)'이라고 불렸다.

현재 챗GPT 이용자를 비롯한 오픈AI의 고객들은 'GPT-4o', 'o1', 'o3-미니', 'GPT-4' 등 모델들을 각자 선택해 활용하고 있다. 최신 모델은 'GPT-4'를 개선한 'GPT-4o'로, 'GPT-4'는 2023년 하반기, 'GPT-4o'는 2024년 상반기 출시됐다.

오픈AI는 'GPT-5'도 지난해 공개하려고 했으나, 예상보다 저조한 성과를 거둬 출시가 연기된 상태다. 이에 그간 연산 시간을 늘려 성능을 높인 'o'시리즈 추론 모델을 새롭게 내세웠다.

샘 알트먼 CEO는 "이후 공개될 'GPT-5'부터는 추론 모델인 'o'시리즈와 'GPT'를 통합하겠다"며 "모델과 제품라인이 복잡해졌음을 잘 알고 있고, 앞으로는 각 모델을 선택해 사용하기보다 그저 잘 작동하길 원한다"고 말했다.
    """
    
    user_query = f"""
당신의 목표는 주어진 기사를 요약하는 것입니다. 
아래 주어진 기사 내용을 요약해주세요.
이전 시도의 요약과 피드백이 있다면, 이를 반영하여 개선된 요약을 작성하세요.

기사 내용: 
{input_article}
    """
    
    evaluator_prompt = """
다음 요약을 평가하십시오:

## 평가기준
1. 핵심 내용 포함 여부 
   - 원문의 핵심 개념과 논리적 흐름이 유지되어야 합니다.  
   - 불필요한 세부 사항은 줄이되, 핵심 정보가 누락되면 감점 요인입니다.  
   - 단어 선택이 다소 달라도, 주요 개념과 의미가 유지되면 PASS 가능합니다.  
   - 원문의 중요 개념 15% 이상이 빠졌다면 FAIL입니다.  

2. 정확성 & 의미 전달  
   - 요약이 원문의 의미를 왜곡하지 않고 정확하게 전달해야 합니다.  
   - 숫자, 인명, 날짜 등 객관적 정보가 틀리면 FAIL입니다.  
   - 문장이 다르게 표현되었더라도 원문의 의미를 유지하면 PASS 가능합니다.  
   - 논리적 비약이 크거나 잘못된 해석이 포함되면 FAIL입니다.  

3. 간결성 및 가독성  
   - 문장이 과하게 길거나 반복적이면 감점 요인입니다.  
   - 직역체 표현은 가독성을 해치지 않으면 허용 가능하지만, 지나치면 FAIL입니다.  
   - 일부 단어의 표현 방식이 달라도 자연스럽다면 PASS 가능합니다.  
   - 문장이 지나치게 어색해서 독해가 어렵다면 FAIL입니다.  

4. 문법 및 표현  
   - 맞춤법, 띄어쓰기 오류가 5개 이상이면 FAIL입니다.  
   - 사소한 문법 실수는 감점 요인이나, 의미 전달에 영향을 주면 FAIL입니다.  
   - 문장이 비문이거나 문맥상 어색한 표현이 많으면 FAIL입니다.  

## 평가결과 응답예시  
- 모든 기준이 충족되었으면 "평가결과 = PASS"를 출력하세요.
- 수정이 필요한 경우, 구체적인 문제점을 지적하고 반드시 개선 방향을 제시하세요.    
- 중대한 오류가 있다면 "평가결과 = FAIL"을 출력하고, 반드시 주요 문제점을 설명하세요.  
요약 결과 :
    """

    final_summary = loop_workflow(user_query, evaluator_prompt, max_retries=5)
    print("\n✅ 최종 요약:\n", final_summary)

# %%
main()
# Out:
# ========== 📝 요약 프롬프트 (시도 1/5) ==========
#
#
# 당신의 목표는 주어진 기사를 요약하는 것입니다.
# 아래 주어진 기사 내용을 요약해주세요.
# 이전 시도의 요약과 피드백이 있다면, 이를 반영하여 개선된 요약을 작성하세요.
#
# 기사 내용:
#
# 오픈AI가 몇 주 안에 새로운 모델인 'GPT-4.5'를 출시하며 분산돼 있던 생성형 인공지능(AI) 모델을 통합키로 했다. 추론용 모델인 'o' 시리즈를 정리하고 비(非)추론 모델인 'GPT' 시리즈로 합칠 예정이다.
#
# 13일 업계에 따르면 샘 알트먼 오픈AI 최고경영자(CEO)는 지난 12일 자신의 X(옛 트위터)에 'GPT-4.5'를 조만간 출시할 것이라고 밝혔다. 현 세대인 'GPT-4o'의 뒤를 잇는 마지막 '비추론 AI'로, 내부적으로는 '오라이언(Orion)'이라고 불렸다.
#
# 현재 챗GPT 이용자를 비롯한 오픈AI의 고객들은 'GPT-4o', 'o1', 'o3-미니', 'GPT-4' 등 모델들을 각자 선택해 활용하고 있다. 최신 모델은 'GPT-4'를 개선한 'GPT-4o'로, 'GPT-4'는 2023년 하반기, 'GPT-4o'는 2024년 상반기 출시됐다.
#
# 오픈AI는 'GPT-5'도 지난해 공개하려고 했으나, 예상보다 저조한 성과를 거둬 출시가 연기된 상태다. 이에 그간 연산 시간을 늘려 성능을 높인 'o'시리즈 추론 모델을 새롭게 내세웠다.
#
# 샘 알트먼 CEO는 "이후 공개될 'GPT-5'부터는 추론 모델인 'o'시리즈와 'GPT'를 통합하겠다"며 "모델과 제품라인이 복잡해졌음을 잘 알고 있고, 앞으로는 각 모델을 선택해 사용하기보다 그저 잘 작동하길 원한다"고 말했다.
#
#
#
# ========== 📝 요약 결과 (시도 1/5) ==========
#
# 오픈AI가 새로운 모델 'GPT-4.5'를 몇 주 내에 출시할 예정이며, 이는 기존의 생성형 인공지능(AI) 모델을 통합하는 첫걸음이 될 것이다. 샘 알트먼 CEO는 'GPT-4.5'가 기존의 추론용 'o' 시리즈와 비추론용 'GPT' 시리즈를 통합하는 모델이라고 밝혔다. 고객들은 현재 다양한 모델을 선택하여 사용하고 있으며, 'GPT-4o'는 'GPT-4'를 개선한 모델이다. 오픈AI는 'GPT-5'의 출시를 연기했으나, 앞으로는 'o' 시리즈와 'GPT' 시리즈를 통합하여 더 간편한 제품 라인을 제공할 계획이다.
#
# ========== 🔍 평가 프롬프트 (시도 1/5) ==========
#
#
# 다음 요약을 평가하십시오:
#
# ## 평가기준
# 1. 핵심 내용 포함 여부
#    - 원문의 핵심 개념과 논리적 흐름이 유지되어야 합니다.
#    - 불필요한 세부 사항은 줄이되, 핵심 정보가 누락되면 감점 요인입니다.
#    - 단어 선택이 다소 달라도, 주요 개념과 의미가 유지되면 PASS 가능합니다.
#    - 원문의 중요 개념 15% 이상이 빠졌다면 FAIL입니다.
#
# 2. 정확성 & 의미 전달
#    - 요약이 원문의 의미를 왜곡하지 않고 정확하게 전달해야 합니다.
#    - 숫자, 인명, 날짜 등 객관적 정보가 틀리면 FAIL입니다.
#    - 문장이 다르게 표현되었더라도 원문의 의미를 유지하면 PASS 가능합니다.
#    - 논리적 비약이 크거나 잘못된 해석이 포함되면 FAIL입니다.
#
# 3. 간결성 및 가독성
#    - 문장이 과하게 길거나 반복적이면 감점 요인입니다.
#    - 직역체 표현은 가독성을 해치지 않으면 허용 가능하지만, 지나치면 FAIL입니다.
#    - 일부 단어의 표현 방식이 달라도 자연스럽다면 PASS 가능합니다.
#    - 문장이 지나치게 어색해서 독해가 어렵다면 FAIL입니다.
#
# 4. 문법 및 표현
#    - 맞춤법, 띄어쓰기 오류가 5개 이상이면 FAIL입니다.
#    - 사소한 문법 실수는 감점 요인이나, 의미 전달에 영향을 주면 FAIL입니다.
#    - 문장이 비문이거나 문맥상 어색한 표현이 많으면 FAIL입니다.
#
# ## 평가결과 응답예시
# - 모든 기준이 충족되었으면 "평가결과 = PASS"를 출력하세요.
# - 수정이 필요한 경우, 구체적인 문제점을 지적하고 반드시 개선 방향을 제시하세요.
# - 중대한 오류가 있다면 "평가결과 = FAIL"을 출력하고, 반드시 주요 문제점을 설명하세요.
# 요약 결과 :
#     오픈AI가 새로운 모델 'GPT-4.5'를 몇 주 내에 출시할 예정이며, 이는 기존의 생성형 인공지능(AI) 모델을 통합하는 첫걸음이 될 것이다. 샘 알트먼 CEO는 'GPT-4.5'가 기존의 추론용 'o' 시리즈와 비추론용 'GPT' 시리즈를 통합하는 모델이라고 밝혔다. 고객들은 현재 다양한 모델을 선택하여 사용하고 있으며, 'GPT-4o'는 'GPT-4'를 개선한 모델이다. 오픈AI는 'GPT-5'의 출시를 연기했으나, 앞으로는 'o' 시리즈와 'GPT' 시리즈를 통합하여 더 간편한 제품 라인을 제공할 계획이다.
#
# ========== 🔍 평가 결과 (시도 1/5) ==========
#
# 평가결과 = PASS
#
# 주어진 요약은 핵심 내용을 잘 포함하고 있으며, 원문의 의미를 왜곡하지 않고 정확하게 전달하고 있습니다. 또한 간결하고 가독성이 있으며 문법적인 오류도 없습니다. 요약의 모든 평가 기준이 충족되었습니다.
#
# ✅ 통과! 최종 요약이 승인되었습니다.
#
#
# ✅ 최종 요약:
#  오픈AI가 새로운 모델 'GPT-4.5'를 몇 주 내에 출시할 예정이며, 이는 기존의 생성형 인공지능(AI) 모델을 통합하는 첫걸음이 될 것이다. 샘 알트먼 CEO는 'GPT-4.5'가 기존의 추론용 'o' 시리즈와 비추론용 'GPT' 시리즈를 통합하는 모델이라고 밝혔다. 고객들은 현재 다양한 모델을 선택하여 사용하고 있으며, 'GPT-4o'는 'GPT-4'를 개선한 모델이다. 오픈AI는 'GPT-5'의 출시를 연기했으나, 앞으로는 'o' 시리즈와 'GPT' 시리즈를 통합하여 더 간편한 제품 라인을 제공할 계획이다.
